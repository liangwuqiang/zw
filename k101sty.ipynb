# %% [markdown]
# # style 绘图风格

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## 复利函数定义

# %%
def sta001(k,nyear,xd):
    d2=np.fv(k,nyear,-xd,-xd);
    d2=round(d2)
    #print(nyear,d2)
    return d2

# %% [markdown]
# ## 循环输出各种风格的图表

# %%
def dr_xtyp(_dat):
    #xtyp=['bmh','dark_background','fivethirtyeight','ggplot','grayscale','default'];
    i=0;
    for xss in plt.style.available:
        plt.figure()
        plt.style.use(xss);
        _dat.plot()
        fss="k101sty/k101sty_"+xss+".png";plt.savefig(fss);
        i+=1;        
        print(i,xss,",",fss)
        plt.show()

# %% [markdown]
# ## 数据生成

# %%
dx05=[sta001(0.05,x,1.4) for x in range(0,40)]
dx10=[sta001(0.10,x,1.4) for x in range(0,40)]
dx15=[sta001(0.15,x,1.4) for x in range(0,40)]
dx20=[sta001(0.20,x,1.4) for x in range(0,40)]

# %%
df=pd.DataFrame(columns=['dx05','dx10','dx15','dx20'])
df['dx05']=dx05
df['dx10']=dx10
df['dx15']=dx15
df['dx20']=dx20
print(df.tail())
# Out:
#      dx05   dx10    dx15     dx20
# 35  134.0  419.0  1420.0   4955.0
# 36  142.0  462.0  1634.0   5947.0
# 37  151.0  510.0  1881.0   7138.0
# 38  160.0  562.0  2165.0   8567.0
# 39  169.0  620.0  2491.0  10281.0

# %% [markdown]
# ## 函数调用

# %%
dr_xtyp(df)
# Out:
# 1 classic , k101sty/k101sty_classic.png
# 2 seaborn-deep , k101sty/k101sty_seaborn-deep.png
# 3 seaborn-talk , k101sty/k101sty_seaborn-talk.png
# 4 seaborn-darkgrid , k101sty/k101sty_seaborn-darkgrid.png
# 5 _classic_test , k101sty/k101sty__classic_test.png
# 6 seaborn-ticks , k101sty/k101sty_seaborn-ticks.png
# 7 seaborn-poster , k101sty/k101sty_seaborn-poster.png
# 8 seaborn-bright , k101sty/k101sty_seaborn-bright.png
# 9 seaborn-notebook , k101sty/k101sty_seaborn-notebook.png
# 10 seaborn-paper , k101sty/k101sty_seaborn-paper.png
# 11 dark_background , k101sty/k101sty_dark_background.png
# 12 seaborn , k101sty/k101sty_seaborn.png
# 13 seaborn-muted , k101sty/k101sty_seaborn-muted.png
# 14 seaborn-white , k101sty/k101sty_seaborn-white.png
# 15 seaborn-dark , k101sty/k101sty_seaborn-dark.png
# 16 ggplot , k101sty/k101sty_ggplot.png
# 17 seaborn-whitegrid , k101sty/k101sty_seaborn-whitegrid.png
# 18 grayscale , k101sty/k101sty_grayscale.png
# 19 fivethirtyeight , k101sty/k101sty_fivethirtyeight.png
# 20 seaborn-dark-palette , k101sty/k101sty_seaborn-dark-palette.png
# 21 seaborn-colorblind , k101sty/k101sty_seaborn-colorblind.png
# 22 bmh , k101sty/k101sty_bmh.png
# 23 seaborn-pastel , k101sty/k101sty_seaborn-pastel.png
